# %%
#load packages

import os, glob, re, pickle
from functools import partial
from collections import OrderedDict
import operator as op
from cytoolz import compose

import pandas as pd
import seaborn as sns
import numpy as np
import scanpy as sc
import anndata as ad
import matplotlib as mpl
import matplotlib.pyplot as plt

from pyscenic.export import export2loom, add_scenic_metadata
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
from pyscenic.aucell import aucell
from pyscenic.binarization import binarize
from pyscenic.rss import regulon_specificity_scores
from pyscenic.plotting import plot_binarization, plot_rss

from IPython.display import HTML, display

print(sc.__version__)
! pip show dask
# Out:
# /home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.manifold.t_sne module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.manifold. Anything that cannot be imported from sklearn.manifold is now part of the private API.
#   warnings.warn(message, FutureWarning)
# 1.5.1
# Name: dask
# Version: 1.0.0
# Summary: Parallel PyData with Task Scheduling
# Home-page: http://github.com/dask/dask/
# Author: None
# Author-email: None
# License: BSD
# Location: /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages
# Requires:
# Required-by: pyscenic, distributed, arboreto

# %%
# Set maximum number of jobs for Scanpy.
sc.settings.njobs = 32

# %%
#Change per dataset
RESOURCES_FOLDERNAME = "../../MacroMono/Healthy/Samsung_Lee_Colon/"


AUXILLIARIES_FOLDERNAME = "../../TrailScenic/Auxillaries/"
RESULTS_FOLDERNAME = "../../MacroMono/Healthy/Samsung_Output/"
FIGURES_FOLDERNAME = "../../TrailScenic/Figures/"

# %%
sc.settings.figdir = FIGURES_FOLDERNAME

# %%
BASE_URL = "http://motifcollections.aertslab.org/v9/logos/"
COLUMN_NAME_LOGO = "MotifLogo"
COLUMN_NAME_MOTIF_ID = "MotifID"
COLUMN_NAME_TARGETS = "TargetGenes"

# %%
def savesvg(fname: str, fig, folder: str=FIGURES_FOLDERNAME) -> None:
    """
    Save figure as vector-based SVG image format.
    """
    fig.tight_layout()
    fig.savefig(os.path.join(folder, fname), format='svg')

# %%
def display_logos(df: pd.DataFrame, top_target_genes: int = 3, base_url: str = BASE_URL):
    """
    :param df:
    :param base_url:
    """
    # Make sure the original dataframe is not altered.
    df = df.copy()
    
    # Add column with URLs to sequence logo.
    def create_url(motif_id):
        return '<img src="{}{}.png" style="max-height:124px;"></img>'.format(base_url, motif_id)
    df[("Enrichment", COLUMN_NAME_LOGO)] = list(map(create_url, df.index.get_level_values(COLUMN_NAME_MOTIF_ID)))
    
    # Truncate TargetGenes.
    def truncate(col_val):
        return sorted(col_val, key=op.itemgetter(1))[:top_target_genes]
    df[("Enrichment", COLUMN_NAME_TARGETS)] = list(map(truncate, df[("Enrichment", COLUMN_NAME_TARGETS)]))
    
    MAX_COL_WIDTH = pd.get_option('display.max_colwidth')
    pd.set_option('display.max_colwidth', -1)
    display(HTML(df.head().to_html(escape=False)))
    pd.set_option('display.max_colwidth', MAX_COL_WIDTH)

# %%
# Downloaded fromm pySCENIC github repo: https://github.com/aertslab/pySCENIC/tree/master/resources
HUMAN_TFS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'hs_hgnc_curated_tfs.txt')
# Ranking databases. Downloaded from cisTargetDB: https://resources.aertslab.org/cistarget/
RANKING_DBS_FNAMES = list(map(lambda fn: os.path.join(AUXILLIARIES_FOLDERNAME, fn),
                       ['hg19-500bp-upstream-10species.mc9nr.feather',
                       'hg19-tss-centered-5kb-10species.mc9nr.feather',
                        'hg19-tss-centered-10kb-10species.mc9nr.feather']))
# Motif annotations. Downloaded from cisTargetDB: https://resources.aertslab.org/cistarget/
MOTIF_ANNOTATIONS_FNAME = os.path.join(AUXILLIARIES_FOLDERNAME, 'motifs-v9-nr.hgnc-m0.001-o0.0.tbl')

# %%
DATASET_ID = "Healthy_Macs_Samsung"
TCGA_CODE = 'Healthy_Macs_Samsung'

# %%
#Adjust


# Downloaded from GEO on 28 FEB 2019.
#CELL_ANNOTATIONS_FNAME = os.path.join(RESOURCES_FOLDERNAME, "GSE115978_cell.annotations.csv")
# Downloaded from Cell Journal website on 1 MAR 2019.
SAMPLE_METADATA_FNAME = os.path.join(RESOURCES_FOLDERNAME, "Meta_Healthy_Macroverse_Samsung_Colon.txt")
# Downloaded from GEO on 1 MAR 2019.
EXP_MTX_TPM_FNAME = os.path.join(RESOURCES_FOLDERNAME, 'TPM_Colon_Samsung_Healthy.txt')
#EXP_MTX_COUNTS_FNAME = os.path.join(RESOURCES_FOLDERNAME, 'GSE115978_counts.csv')

# %%
METADATA_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.metadata.csv'.format(DATASET_ID))
EXP_MTX_QC_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.qc.tpm.csv'.format(DATASET_ID))
ADJACENCIES_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.adjacencies.tsv'.format(DATASET_ID))
MOTIFS_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.motifs.csv'.format(DATASET_ID))
REGULONS_DAT_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.regulons.dat'.format(DATASET_ID))
AUCELL_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.auc.csv'.format(DATASET_ID))
BIN_MTX_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.bin.csv'.format(DATASET_ID))
THR_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.thresholds.csv'.format(DATASET_ID))
ANNDATA_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}.h5ad'.format(DATASET_ID))
LOOM_FNAME = os.path.join(RESULTS_FOLDERNAME, '{}_{}.loom'.format(TCGA_CODE, DATASET_ID))

# %% [markdown]
# Reading TPM and QC

# %%
#Read table
# df_tpm = sc.read_text(EXP_MTX_TPM_FNAME, delimiter='\t', first_column_names=True)
df_tpm = pd.read_csv(EXP_MTX_TPM_FNAME, sep='\t', index_col=0)
display(df_tpm.head())
df_tpm.shape
# Out:
#           SMC01-N_AACTCCCGTCCCTACT  SMC01-N_AACTCTTGTGGCAAAC  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         9
# A2M-AS1                          0                         0
#
#           SMC01-N_ACATACGCATGGAATA  SMC01-N_AGAGCGAAGGGTTCCC  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              1                        10
# A2M-AS1                          0                         0
#
#           SMC01-N_ATGAGGGAGTTTGCGT  SMC01-N_CATATTCAGTTCGATC  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         0
# A2M-AS1                          0                         0
#
#           SMC01-N_CCGGGATTCTCGAGTA  SMC01-N_CGGAGCTAGTCGAGTG  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              1                         0
# A2M-AS1                          0                         0
#
#           SMC01-N_CGTCAGGGTGAGTGAC  SMC01-N_CTACGTCTCTTGTACT  ...  \
# A1BG                             0                         0  ...
# A1BG-AS1                         0                         0  ...
# A1CF                             0                         0  ...
# A2M                              2                         2  ...
# A2M-AS1                          0                         0  ...
#
#           SMC10-N_TCGCGTTTCGCTTAGA  SMC10-N_TCGGTAACACTGTCGG  \
# A1BG                             0                         1
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         0
# A2M-AS1                          0                         0
#
#           SMC10-N_TGAGCCGGTTCAGTAC  SMC10-N_TGCGTGGGTTGATTCG  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         2
# A2M-AS1                          0                         0
#
#           SMC10-N_TGGCTGGTCGCCATAA  SMC10-N_TTATGCTTCCACGTGG  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              1                         1
# A2M-AS1                          0                         0
#
#           SMC10-N_TTCGGTCTCTATCGCC  SMC10-N_TTCTACAAGTCCTCCT  \
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         0
# A2M-AS1                          0                         0
#
#           SMC10-N_TTCTCCTTCGACGGAA  SMC10-N_TTGAACGGTCTCCATC
# A1BG                             0                         0
# A1BG-AS1                         0                         0
# A1CF                             0                         0
# A2M                              0                         2
# A2M-AS1                          0                         0
#
# [5 rows x 226 columns]
# (33694, 226)

# %%
# transpose the TPM HERE
df_tpm_T = df_tpm.T

# %%
#TRANSFORM MATRIX ONLY
import sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

#Initialize a scaler, then apply it to the features
scaler = MinMaxScaler(feature_range=(0,2)) # default=(0, 1)
numerical = list(df_tpm_T.columns)

df_tpm_T_minmax = pd.DataFrame(data = df_tpm_T)
df_tpm_T_minmax[numerical] = scaler.fit_transform(df_tpm_T[numerical])

# Show an example of a record with scaling applied
display(df_tpm_T_minmax.head(n = 5))

# %%
# df_samples = pd.read_csv(SAMPLE_METADATA_FNAME, sep='\t')
df_samples = pd.read_csv(SAMPLE_METADATA_FNAME, sep='\t', index_col=0) # if you want first column to be the index
df_samples.rename(columns={'**UMAP1_md0.001_k150': 'UMAP1', '**UMAP2_md0.001_k150': 'UMAP2', '**Phenograph_md0.001_k150': 'Phenograph', 
                          }, inplace=True)

df_samples.head()
# Out:
#                           Tissue Ascites-1 Blood-2 Breast-3 Colon-4 Stomach-5 Kidney-6 Liver-7 Lung-8 Pancreas-9 Skin-10 Spleen-11 Tonsil-12  \
# SMC01-N_AACTCCCGTCCCTACT                                                  4
# SMC01-N_AACTCTTGTGGCAAAC                                                  4
# SMC01-N_ACATACGCATGGAATA                                                  4
# SMC01-N_AGAGCGAAGGGTTCCC                                                  4
# SMC01-N_ATGAGGGAGTTTGCGT                                                  4
#
#                          Tissue    Study           Patients  Study-No  \
# SMC01-N_AACTCCCGTCCCTACT  Colon  Samsung  Samsung_Healthy_1        36
# SMC01-N_AACTCTTGTGGCAAAC  Colon  Samsung  Samsung_Healthy_1        36
# SMC01-N_ACATACGCATGGAATA  Colon  Samsung  Samsung_Healthy_1        36
# SMC01-N_AGAGCGAAGGGTTCCC  Colon  Samsung  Samsung_Healthy_1        36
# SMC01-N_ATGAGGGAGTTTGCGT  Colon  Samsung  Samsung_Healthy_1        36
#
#                           Global Healthy-1_Cancer-2_Other-3  \
# SMC01-N_AACTCCCGTCCCTACT                                  1
# SMC01-N_AACTCTTGTGGCAAAC                                  1
# SMC01-N_ACATACGCATGGAATA                                  1
# SMC01-N_AGAGCGAAGGGTTCCC                                  1
# SMC01-N_ATGAGGGAGTTTGCGT                                  1
#
#                           Condition per tissue  Patient No  \
# SMC01-N_AACTCCCGTCCCTACT                     1           1
# SMC01-N_AACTCTTGTGGCAAAC                     1           1
# SMC01-N_ACATACGCATGGAATA                     1           1
# SMC01-N_AGAGCGAAGGGTTCCC                     1           1
# SMC01-N_ATGAGGGAGTTTGCGT                     1           1
#
#                           CellType MirgDC-1 DC1-2 DC2-3 MacoMono-4  \
# SMC01-N_AACTCCCGTCCCTACT                                         4
# SMC01-N_AACTCTTGTGGCAAAC                                         4
# SMC01-N_ACATACGCATGGAATA                                         4
# SMC01-N_AGAGCGAAGGGTTCCC                                         4
# SMC01-N_ATGAGGGAGTTTGCGT                                         4
#
#                           UMAP1_ByTissue  ...  Phenograph_md0.001_k100  \
# SMC01-N_AACTCCCGTCCCTACT      728.522894  ...                        1
# SMC01-N_AACTCTTGTGGCAAAC      793.561794  ...                       13
# SMC01-N_ACATACGCATGGAATA      920.405479  ...                        5
# SMC01-N_AGAGCGAAGGGTTCCC     1041.911520  ...                        7
# SMC01-N_ATGAGGGAGTTTGCGT     1027.583236  ...                        5
#
#                                 UMAP1        UMAP2  Phenograph  \
# SMC01-N_AACTCCCGTCCCTACT  7388.413084  3137.684199           5
# SMC01-N_AACTCTTGTGGCAAAC  3581.764920  5278.849458           7
# SMC01-N_ACATACGCATGGAATA  3029.536182  4822.213721           2
# SMC01-N_AGAGCGAAGGGTTCCC  1388.725160  3853.947521           3
# SMC01-N_ATGAGGGAGTTTGCGT  2806.556856  4826.359400           2
#
#                           UMAP1_md0.005_k100  UMAP2_md0.005_k100  \
# SMC01-N_AACTCCCGTCCCTACT         7896.658689         2917.895745
# SMC01-N_AACTCTTGTGGCAAAC         4540.143945         6395.617257
# SMC01-N_ACATACGCATGGAATA         4161.494683         7193.372248
# SMC01-N_AGAGCGAAGGGTTCCC         3097.507313         4244.649495
# SMC01-N_ATGAGGGAGTTTGCGT         3855.531861         7108.626219
#
#                           Phenograph_md0.005_k100  UMAP1_md0.005_k150  \
# SMC01-N_AACTCCCGTCCCTACT                        1         7413.556557
# SMC01-N_AACTCTTGTGGCAAAC                       13         3709.731085
# SMC01-N_ACATACGCATGGAATA                        5         3303.671401
# SMC01-N_AGAGCGAAGGGTTCCC                        7         1363.265914
# SMC01-N_ATGAGGGAGTTTGCGT                        5         3064.760422
#
#                           UMAP2_md0.005_k150  Phenograph_md0.005_k150
# SMC01-N_AACTCCCGTCCCTACT         3083.216526                        5
# SMC01-N_AACTCTTGTGGCAAAC         5140.562114                        7
# SMC01-N_ACATACGCATGGAATA         4661.794719                        2
# SMC01-N_AGAGCGAAGGGTTCCC         3876.192858                        3
# SMC01-N_ATGAGGGAGTTTGCGT         4617.988419                        2
#
# [5 rows x 72 columns]

# %%
df_samples
# Out:
#                           Tissue Ascites-1 Blood-2 Breast-3 Colon-4 Stomach-5 Kidney-6 Liver-7 Lung-8 Pancreas-9 Skin-10 Spleen-11 Tonsil-12  \
# SMC01-N_AACTCCCGTCCCTACT                                                  4
# SMC01-N_AACTCTTGTGGCAAAC                                                  4
# SMC01-N_ACATACGCATGGAATA                                                  4
# SMC01-N_AGAGCGAAGGGTTCCC                                                  4
# SMC01-N_ATGAGGGAGTTTGCGT                                                  4
# ...                                                                     ...
# SMC10-N_TTATGCTTCCACGTGG                                                  4
# SMC10-N_TTCGGTCTCTATCGCC                                                  4
# SMC10-N_TTCTACAAGTCCTCCT                                                  4
# SMC10-N_TTCTCCTTCGACGGAA                                                  4
# SMC10-N_TTGAACGGTCTCCATC                                                  4
#
#                          Tissue    Study            Patients  Study-No  \
# SMC01-N_AACTCCCGTCCCTACT  Colon  Samsung   Samsung_Healthy_1        36
# SMC01-N_AACTCTTGTGGCAAAC  Colon  Samsung   Samsung_Healthy_1        36
# SMC01-N_ACATACGCATGGAATA  Colon  Samsung   Samsung_Healthy_1        36
# SMC01-N_AGAGCGAAGGGTTCCC  Colon  Samsung   Samsung_Healthy_1        36
# SMC01-N_ATGAGGGAGTTTGCGT  Colon  Samsung   Samsung_Healthy_1        36
# ...                         ...      ...                 ...       ...
# SMC10-N_TTATGCTTCCACGTGG  Colon  Samsung  Samsung_Healthy_10        36
# SMC10-N_TTCGGTCTCTATCGCC  Colon  Samsung  Samsung_Healthy_10        36
# SMC10-N_TTCTACAAGTCCTCCT  Colon  Samsung  Samsung_Healthy_10        36
# SMC10-N_TTCTCCTTCGACGGAA  Colon  Samsung  Samsung_Healthy_10        36
# SMC10-N_TTGAACGGTCTCCATC  Colon  Samsung  Samsung_Healthy_10        36
#
#                           Global Healthy-1_Cancer-2_Other-3  \
# SMC01-N_AACTCCCGTCCCTACT                                  1
# SMC01-N_AACTCTTGTGGCAAAC                                  1
# SMC01-N_ACATACGCATGGAATA                                  1
# SMC01-N_AGAGCGAAGGGTTCCC                                  1
# SMC01-N_ATGAGGGAGTTTGCGT                                  1
# ...                                                     ...
# SMC10-N_TTATGCTTCCACGTGG                                  1
# SMC10-N_TTCGGTCTCTATCGCC                                  1
# SMC10-N_TTCTACAAGTCCTCCT                                  1
# SMC10-N_TTCTCCTTCGACGGAA                                  1
# SMC10-N_TTGAACGGTCTCCATC                                  1
#
#                           Condition per tissue  Patient No  \
# SMC01-N_AACTCCCGTCCCTACT                     1           1
# SMC01-N_AACTCTTGTGGCAAAC                     1           1
# SMC01-N_ACATACGCATGGAATA                     1           1
# SMC01-N_AGAGCGAAGGGTTCCC                     1           1
# SMC01-N_ATGAGGGAGTTTGCGT                     1           1
# ...                                        ...         ...
# SMC10-N_TTATGCTTCCACGTGG                     1          10
# SMC10-N_TTCGGTCTCTATCGCC                     1          10
# SMC10-N_TTCTACAAGTCCTCCT                     1          10
# SMC10-N_TTCTCCTTCGACGGAA                     1          10
# SMC10-N_TTGAACGGTCTCCATC                     1          10
#
#                           CellType MirgDC-1 DC1-2 DC2-3 MacoMono-4  \
# SMC01-N_AACTCCCGTCCCTACT                                         4
# SMC01-N_AACTCTTGTGGCAAAC                                         4
# SMC01-N_ACATACGCATGGAATA                                         4
# SMC01-N_AGAGCGAAGGGTTCCC                                         4
# SMC01-N_ATGAGGGAGTTTGCGT                                         4
# ...                                                            ...
# SMC10-N_TTATGCTTCCACGTGG                                         4
# SMC10-N_TTCGGTCTCTATCGCC                                         4
# SMC10-N_TTCTACAAGTCCTCCT                                         4
# SMC10-N_TTCTCCTTCGACGGAA                                         4
# SMC10-N_TTGAACGGTCTCCATC                                         4
#
#                           UMAP1_ByTissue  ...  Phenograph_md0.001_k100  \
# SMC01-N_AACTCCCGTCCCTACT      728.522894  ...                        1
# SMC01-N_AACTCTTGTGGCAAAC      793.561794  ...                       13
# SMC01-N_ACATACGCATGGAATA      920.405479  ...                        5
# SMC01-N_AGAGCGAAGGGTTCCC     1041.911520  ...                        7
# SMC01-N_ATGAGGGAGTTTGCGT     1027.583236  ...                        5
# ...                                  ...  ...                      ...
# SMC10-N_TTATGCTTCCACGTGG      949.171506  ...                        5
# SMC10-N_TTCGGTCTCTATCGCC     1144.767843  ...                       17
# SMC10-N_TTCTACAAGTCCTCCT     1161.833563  ...                        6
# SMC10-N_TTCTCCTTCGACGGAA      714.915572  ...                       17
# SMC10-N_TTGAACGGTCTCCATC     1028.317127  ...                       13
#
#                                 UMAP1        UMAP2  Phenograph  \
# SMC01-N_AACTCCCGTCCCTACT  7388.413084  3137.684199           5
# SMC01-N_AACTCTTGTGGCAAAC  3581.764920  5278.849458           7
# SMC01-N_ACATACGCATGGAATA  3029.536182  4822.213721           2
# SMC01-N_AGAGCGAAGGGTTCCC  1388.725160  3853.947521           3
# SMC01-N_ATGAGGGAGTTTGCGT  2806.556856  4826.359400           2
# ...                               ...          ...         ...
# SMC10-N_TTATGCTTCCACGTGG  2791.649470  4915.005621           2
# SMC10-N_TTCGGTCTCTATCGCC  7206.279865  3432.721042           5
# SMC10-N_TTCTACAAGTCCTCCT  7881.787548  1102.548340           8
# SMC10-N_TTCTCCTTCGACGGAA  8374.662360  3243.579251           5
# SMC10-N_TTGAACGGTCTCCATC  4157.663003  5121.916611           7
#
#                           UMAP1_md0.005_k100  UMAP2_md0.005_k100  \
# SMC01-N_AACTCCCGTCCCTACT         7896.658689         2917.895745
# SMC01-N_AACTCTTGTGGCAAAC         4540.143945         6395.617257
# SMC01-N_ACATACGCATGGAATA         4161.494683         7193.372248
# SMC01-N_AGAGCGAAGGGTTCCC         3097.507313         4244.649495
# SMC01-N_ATGAGGGAGTTTGCGT         3855.531861         7108.626219
# ...                                      ...                 ...
# SMC10-N_TTATGCTTCCACGTGG         3984.783078         7070.785500
# SMC10-N_TTCGGTCTCTATCGCC         7178.248092         3323.873218
# SMC10-N_TTCTACAAGTCCTCCT         8201.491873         1077.360780
# SMC10-N_TTCTCCTTCGACGGAA         8491.108417         3096.566489
# SMC10-N_TTGAACGGTCTCCATC         5037.315490         5915.780105
#
#                           Phenograph_md0.005_k100  UMAP1_md0.005_k150  \
# SMC01-N_AACTCCCGTCCCTACT                        1         7413.556557
# SMC01-N_AACTCTTGTGGCAAAC                       13         3709.731085
# SMC01-N_ACATACGCATGGAATA                        5         3303.671401
# SMC01-N_AGAGCGAAGGGTTCCC                        7         1363.265914
# SMC01-N_ATGAGGGAGTTTGCGT                        5         3064.760422
# ...                                           ...                 ...
# SMC10-N_TTATGCTTCCACGTGG                        5         3114.993502
# SMC10-N_TTCGGTCTCTATCGCC                       17         7242.094421
# SMC10-N_TTCTACAAGTCCTCCT                        6         7940.109646
# SMC10-N_TTCTCCTTCGACGGAA                       17         8325.930197
# SMC10-N_TTGAACGGTCTCCATC                       13         4515.085994
#
#                           UMAP2_md0.005_k150  Phenograph_md0.005_k150
# SMC01-N_AACTCCCGTCCCTACT         3083.216526                        5
# SMC01-N_AACTCTTGTGGCAAAC         5140.562114                        7
# SMC01-N_ACATACGCATGGAATA         4661.794719                        2
# SMC01-N_AGAGCGAAGGGTTCCC         3876.192858                        3
# SMC01-N_ATGAGGGAGTTTGCGT         4617.988419                        2
# ...                                      ...                      ...
# SMC10-N_TTATGCTTCCACGTGG         4603.969250                        2
# SMC10-N_TTCGGTCTCTATCGCC         3398.233501                        5
# SMC10-N_TTCTACAAGTCCTCCT         1069.567636                        8
# SMC10-N_TTCTCCTTCGACGGAA         3169.509477                        5
# SMC10-N_TTGAACGGTCTCCATC         5039.523247                        7
#
# [226 rows x 72 columns]

# %%
adata = sc.AnnData(X=df_tpm_T.sort_index())
df_obs = df_samples[['Tissue','UMAP1', 'UMAP2', 'Phenograph']].sort_index()

adata.obs = df_obs
adata.var_names_make_unique()
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# Store non-log transformed data as raw. This data can be used via the use_raw parameters available for many functions.
# In the scanpy's tutorials this is used to stored all genes in log-transformed counts before retaining only Highly Variable Genes (HVG). 
# Because in this case no filtering is done we use this feature to store raw counts.
adata.raw = adata 
sc.pp.log1p(adata)
adata
# Out:
# AnnData object with n_obs × n_vars = 226 × 10196
#     obs: 'Tissue', 'UMAP1', 'UMAP2', 'Phenograph', 'n_genes'
#     var: 'n_cells'
#     uns: 'log1p'

# %%
df_tpm_F = df_tpm_T.loc[adata.obs.index.values].copy()

# %%
adata.write_h5ad(ANNDATA_FNAME) # Categorical dtypes are created.
# Out:
# ... storing 'Tissue' as categorical

# %%
adata.to_df().to_csv(EXP_MTX_QC_FNAME)

# %%
# adata.to_df()

# %% [markdown]
# STEP 1: Network inference based on GRNBoost2 from CLI
# For this step the CLI version of SCENIC is used. This step can be deployed on an High Performance Computing system.
#
# Output: List of adjacencies between a TF and its targets stored in ADJACENCIES_FNAME.
#
# Check Server how much RAM is avialable and adjust the num_workers

# %%
import sys
# !{sys.executable} -m pip install fsspec>=0.3.3
# !{sys.executable} -m pip install dask[dataframe] --upgrade
# !{sys.executable} -m pip install distributed -U
# Out:
# Collecting dask[dataframe]
#   Using cached dask-2.25.0-py3-none-any.whl (834 kB)
# Requirement already satisfied, skipping upgrade: pyyaml in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (5.3.1)
# Requirement already satisfied, skipping upgrade: fsspec>=0.6.0; extra == "dataframe" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (0.7.4)
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0; extra == "dataframe" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (0.25.3)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2; extra == "dataframe" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (0.10.0)
# Requirement already satisfied, skipping upgrade: partd>=0.3.10; extra == "dataframe" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.0; extra == "dataframe" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from dask[dataframe]) (1.18.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2020.1)
# Requirement already satisfied, skipping upgrade: locket in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]) (0.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (1.15.0)
# ERROR: pyscenic 0.10.0 has requirement dask==1.0.0, but you'll have dask 2.25.0 which is incompatible.
# Installing collected packages: dask
#   Attempting uninstall: dask
#     Found existing installation: dask 1.0.0
#     Uninstalling dask-1.0.0:
#       Successfully uninstalled dask-1.0.0
# Successfully installed dask-2.25.0
# Collecting distributed
#   Using cached distributed-2.25.0-py3-none-any.whl (652 kB)
# Requirement already satisfied, skipping upgrade: contextvars; python_version < "3.7" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (2.4)
# Requirement already satisfied, skipping upgrade: tblib>=1.6.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (1.6.0)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (0.10.0)
# Requirement already satisfied, skipping upgrade: tornado>=5; python_version < "3.8" in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (6.0.4)
# Requirement already satisfied, skipping upgrade: psutil>=5.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (5.7.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (5.3.1)
# Requirement already satisfied, skipping upgrade: zict>=0.1.3 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (2.0.0)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.5.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (1.5.0)
# Requirement already satisfied, skipping upgrade: dask>=2.9.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (2.25.0)
# Requirement already satisfied, skipping upgrade: msgpack>=0.6.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (1.0.0)
# Requirement already satisfied, skipping upgrade: click>=6.6 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (7.1.2)
# Requirement already satisfied, skipping upgrade: sortedcontainers!=2.0.0,!=2.0.1 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (2.2.2)
# Requirement already satisfied, skipping upgrade: setuptools in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed) (47.3.1.post20200622)
# Requirement already satisfied, skipping upgrade: immutables>=0.9 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from contextvars; python_version < "3.7"->distributed) (0.14)
# Requirement already satisfied, skipping upgrade: heapdict in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from zict>=0.1.3->distributed) (1.0.1)
# ERROR: pyscenic 0.10.0 has requirement dask==1.0.0, but you'll have dask 2.25.0 which is incompatible.
# ERROR: pyscenic 0.10.0 has requirement distributed<2.0.0,>=1.21.6, but you'll have distributed 2.25.0 which is incompatible.
# Installing collected packages: distributed
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.28.1
#     Uninstalling distributed-1.28.1:
#       Successfully uninstalled distributed-1.28.1
# Successfully installed distributed-2.25.0

# %%
# !pyscenic grn {EXP_MTX_QC_FNAME} {HUMAN_TFS_FNAME} -o {ADJACENCIES_FNAME} --num_workers 15
# Out:
# 2020-09-02 12:49:24,916 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2020-09-02 12:49:26,049 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# /home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages/distributed/node.py:155: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46465 instead
#   http_address["port"], self.http_server.port
# preparing dask client
# parsing input
# /home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages/arboreto/algo.py:214: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   expression_matrix = expression_data.as_matrix()
# creating dask graph
# 15 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
#
# 2020-09-02 12:50:39,558 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
# check presence of output path
# !ls ../../MacroMono/Healthy/Samsung_Lee_Colon/
# Out:
# Meta_Healthy_Macroverse_Samsung_Colon.txt  TPM_Colon_Samsung_Healthy.txt

# %%
# head output results
# !head ../../TrailScenic/Results/MigrDCverse_Maier.adjacencies.tsv

# %%
import sys

# !{sys.executable} -m pip install dask==1.0.0 distributed'>=1.21.6,<2.0.0'
# Out:
# Collecting dask==1.0.0
#   Using cached dask-1.0.0-py2.py3-none-any.whl (685 kB)
# Collecting distributed<2.0.0,>=1.21.6
#   Using cached distributed-1.28.1-py2.py3-none-any.whl (517 kB)
# Requirement already satisfied: msgpack in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (1.0.0)
# Requirement already satisfied: zict>=0.1.3 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (2.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (2.2.2)
# Requirement already satisfied: six in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (1.15.0)
# Requirement already satisfied: tblib in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (1.6.0)
# Requirement already satisfied: tornado>=5 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (6.0.4)
# Requirement already satisfied: click>=6.6 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (7.1.2)
# Requirement already satisfied: cloudpickle>=0.2.2 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (1.5.0)
# Requirement already satisfied: toolz>=0.7.4 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (0.10.0)
# Requirement already satisfied: pyyaml in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (5.3.1)
# Requirement already satisfied: psutil>=5.0 in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from distributed<2.0.0,>=1.21.6) (5.7.0)
# Requirement already satisfied: heapdict in /scbio4/home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages (from zict>=0.1.3->distributed<2.0.0,>=1.21.6) (1.0.1)
# Installing collected packages: dask, distributed
#   Attempting uninstall: dask
#     Found existing installation: dask 2.25.0
#     Uninstalling dask-2.25.0:
#       Successfully uninstalled dask-2.25.0
#   Attempting uninstall: distributed
#     Found existing installation: distributed 2.25.0
#     Uninstalling distributed-2.25.0:
#       Successfully uninstalled distributed-2.25.0
# Successfully installed dask-1.0.0 distributed-1.28.1

# %% [markdown]
# STEP 2-3: Regulon prediction aka cisTarget from CLI
# For this step the CLI version of SCENIC is used. This step can be deployed on an High Performance Computing system.
#
# Output: List of adjacencies between a TF and its targets stored in MOTIFS_FNAME.

# %%
DBS_PARAM = ' '.join(RANKING_DBS_FNAMES)

# %%
# !pyscenic ctx {ADJACENCIES_FNAME} {DBS_PARAM} \
            --annotations_fname {MOTIF_ANNOTATIONS_FNAME} \
            --expression_mtx_fname {EXP_MTX_QC_FNAME} \
            --output {MOTIFS_FNAME} \
            --num_workers 20
# Out:
# /home/kevinm/anaconda3/envs/pyscenic_py36/lib/python3.6/site-packages/dask/config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
#
# 2020-09-02 12:50:51,237 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2020-09-02 12:50:51,660 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2020-09-02 12:50:52,840 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2020-09-02 12:50:52,840 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [False].
#
# 2020-09-02 12:51:05,225 - pyscenic.utils - INFO - Creating modules.
#
# 2020-09-02 12:51:55,057 - pyscenic.cli.pyscenic - INFO - Loading databases.
#
# 2020-09-02 12:51:55,057 - pyscenic.cli.pyscenic - INFO - Calculating regulons.
# [                                        ] | 0% Completed | 21.3s
# 2020-09-02 12:52:17,599 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF513 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 23.6s
# 2020-09-02 12:52:19,909 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF589 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 26.7s
# 2020-09-02 12:52:22,995 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF589 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 26.9s
# 2020-09-02 12:52:23,232 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF605 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 27.0s
# 2020-09-02 12:52:23,270 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF699 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 27.4s
# 2020-09-02 12:52:23,658 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF628 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 27.6s
# 2020-09-02 12:52:23,884 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF639 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 28.1s
# 2020-09-02 12:52:24,382 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF668 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 28.9s
# 2020-09-02 12:52:25,189 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF69 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 29.1s
# 2020-09-02 12:52:25,440 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF699 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 29.8s
# 2020-09-02 12:52:26,106 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF736 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 31.3s
# 2020-09-02 12:52:27,581 - pyscenic.transform - WARNING - Less than 80% of the genes in VENTX could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 32.1s
# 2020-09-02 12:52:28,419 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for GLI4 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 32.9s
# 2020-09-02 12:52:29,219 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN29 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 35.7s
# 2020-09-02 12:52:32,045 - pyscenic.transform - WARNING - Less than 80% of the genes in NFE2L3 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 0% Completed | 35.9s
# 2020-09-02 12:52:32,252 - pyscenic.transform - WARNING - Less than 80% of the genes in FLI1 could be mapped to hg19-500bp-upstream-10species.mc9nr. Skipping this module.
# [                                        ] | 1% Completed | 36.9s
# 2020-09-02 12:52:33,220 - pyscenic.transform - WARNING - Less than 80% of the genes in ZN
could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 17.3s
# 2020-09-02 13:05:13,706 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF699 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 17.6s
# 2020-09-02 13:05:13,937 - pyscenic.transform - WARNING - Less than 80% of the genes in ELK4 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 18.1s
# 2020-09-02 13:05:14,508 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RORA could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 19.0s
# 2020-09-02 13:05:15,256 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF736 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 20.3s
# 2020-09-02 13:05:16,615 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF765 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 21.5s
# 2020-09-02 13:05:17,786 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF787 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [############################            ] | 72% Completed | 13min 27.9s
# 2020-09-02 13:05:24,222 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF513 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [#############################           ] | 73% Completed | 13min 36.6s
# 2020-09-02 13:05:32,944 - pyscenic.transform - WARNING - Less than 80% of the genes in ZSCAN29 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [###############################         ] | 79% Completed | 14min 26.8s
# 2020-09-02 13:06:23,133 - pyscenic.transform - WARNING - Less than 80% of the genes in IKZF5 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [################################        ] | 80% Completed | 14min 28.8s
# 2020-09-02 13:06:25,126 - pyscenic.transform - WARNING - Less than 80% of the genes in NFE2L3 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [################################        ] | 80% Completed | 14min 32.0s
# 2020-09-02 13:06:28,340 - pyscenic.transform - WARNING - Less than 80% of the genes in FLI1 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [################################        ] | 80% Completed | 14min 36.1s
# 2020-09-02 13:06:32,404 - pyscenic.transform - WARNING - Less than 80% of the genes in SP4 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [################################        ] | 81% Completed | 14min 45.3s
# 2020-09-02 13:06:41,663 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FOSB could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [##################################      ] | 86% Completed | 15min 37.5s
# 2020-09-02 13:07:33,793 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FLI1 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [##################################      ] | 86% Completed | 15min 45.8s
# 2020-09-02 13:07:42,070 - pyscenic.transform - WARNING - Less than 80% of the genes in FOXO4 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [##################################      ] | 86% Completed | 15min 47.9s
# 2020-09-02 13:07:44,142 - pyscenic.transform - WARNING - Less than 80% of the genes in TBX3 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [###################################     ] | 87% Completed | 15min 57.0s
# 2020-09-02 13:07:53,314 - pyscenic.transform - WARNING - Less than 80% of the genes in GLI4 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [###################################     ] | 88% Completed | 16min 22.3s
# 2020-09-02 13:08:18,628 - pyscenic.transform - WARNING - Less than 80% of the genes in THAP1 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [####################################    ] | 90% Completed | 16min 30.5s
# 2020-09-02 13:08:26,874 - pyscenic.transform - WARNING - Less than 80% of the genes in HOXB7 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [####################################    ] | 90% Completed | 16min 30.6s
# 2020-09-02 13:08:26,981 - pyscenic.transform - WARNING - Less than 80% of the genes in HSF1 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [####################################    ] | 90% Completed | 16min 43.8s
# 2020-09-02 13:08:40,093 - pyscenic.transform - WARNING - Less than 80% of the genes in IKZF5 could be mapped to hg19-tss-centered-10kb-10species.mc9nr. Skipping this module.
# [########################################] | 100% Completed | 22min 41.6s
#
# 2020-09-02 13:14:38,048 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
df_motifs = load_motifs(MOTIFS_FNAME)

# %%
# !head {MOTIFS_FNAME}

# %% [markdown]
# AUCELL Step
#
# First checking genes

# %%
nGenesDetectedPerCell = np.sum(df_tpm>0, axis=1)
percentiles = nGenesDetectedPerCell.quantile([.01, .05, .10, .50, 1])
print(percentiles)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5), dpi=150)
sns.distplot(nGenesDetectedPerCell, norm_hist=False, kde=False, bins='fd')
for i,x in enumerate(percentiles):
    fig.gca().axvline(x=x, ymin=0,ymax=1, color='red')
    ax.text(x=x, y=ax.get_ylim()[1], s=f'{int(x)} ({percentiles.index.values[i]*100}%)', color='red', rotation=30, size='x-small',rotation_mode='anchor' )
ax.set_xlabel('# of genes')
ax.set_ylabel('# of cells')
fig.tight_layout()

# %%
df_motifs = load_motifs(MOTIFS_FNAME)
regulons = df2regulons(df_motifs)
# Pickle these regulons.
with open(REGULONS_DAT_FNAME, 'wb') as f:
    pickle.dump(regulons, f)
# Out:
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []

# %%
# %%time
auc_mtx = aucell(df_tpm_F, regulons, num_workers=32)
auc_mtx.to_csv(AUCELL_MTX_FNAME)
# Out:
# CPU times: user 8 s, sys: 3.4 s, total: 11.4 s
# Wall time: 14 s

# %%
auc_mtx = pd.read_csv(AUCELL_MTX_FNAME, index_col=0)

# %%
auc_mtx
# Out:
#                            AHRR(+)  ARID3A(+)   ARNT(+)   ATF1(+)   ATF2(+)  \
# Cell
# SMC01-N_AACTCCCGTCCCTACT  0.040694   0.050123  0.146800  0.151504  0.026231
# SMC01-N_AACTCTTGTGGCAAAC  0.049680   0.015278  0.202667  0.074044  0.053344
# SMC01-N_ACATACGCATGGAATA  0.053243   0.085311  0.143175  0.070039  0.050894
# SMC01-N_AGAGCGAAGGGTTCCC  0.037011   0.040241  0.107707  0.048116  0.032943
# SMC01-N_ATGAGGGAGTTTGCGT  0.085284   0.041574  0.223104  0.063679  0.037870
# ...                            ...        ...       ...       ...       ...
# SMC10-N_TTATGCTTCCACGTGG  0.045889   0.058280  0.137478  0.055634  0.056252
# SMC10-N_TTCGGTCTCTATCGCC  0.041415   0.134708  0.140662  0.081518  0.050904
# SMC10-N_TTCTACAAGTCCTCCT  0.048902   0.077763  0.089594  0.088762  0.036153
# SMC10-N_TTCTCCTTCGACGGAA  0.050780   0.042480  0.138812  0.082621  0.051599
# SMC10-N_TTGAACGGTCTCCATC  0.060494   0.032628  0.058011  0.073081  0.026377
#
#                            ATF3(+)   ATF4(+)   ATF6(+)  ATF6B(+)   ATF7(+)  \
# Cell
# SMC01-N_AACTCCCGTCCCTACT  0.144559  0.224846  0.105522  0.037143  0.053446
# SMC01-N_AACTCTTGTGGCAAAC  0.176578  0.200587  0.141568  0.096421  0.110165
# SMC01-N_ACATACGCATGGAATA  0.158217  0.185201  0.137671  0.058695  0.069919
# SMC01-N_AGAGCGAAGGGTTCCC  0.180369  0.169854  0.156395  0.054143  0.108752
# SMC01-N_ATGAGGGAGTTTGCGT  0.185470  0.159960  0.130520  0.063915  0.096927
# ...                            ...       ...       ...       ...       ...
# SMC10-N_TTATGCTTCCACGTGG  0.133420  0.140491  0.124772  0.053647  0.087470
# SMC10-N_TTCGGTCTCTATCGCC  0.162420  0.206830  0.116514  0.060733  0.068994
# SMC10-N_TTCTACAAGTCCTCCT  0.141417  0.181010  0.103265  0.052323  0.128835
# SMC10-N_TTCTCCTTCGACGGAA  0.145904  0.201179  0.112036  0.078531  0.106011
# SMC10-N_TTGAACGGTCTCCATC  0.127455  0.166762  0.106518  0.061671  0.097171
#
#                           ...  ZNF655(+)  ZNF740(+)  ZNF76(+)  ZNF768(+)  \
# Cell                      ...
# SMC01-N_AACTCCCGTCCCTACT  ...   0.228420   0.021117  0.033070   0.000000
# SMC01-N_AACTCTTGTGGCAAAC  ...   0.000000   0.098391  0.028013   0.075621
# SMC01-N_ACATACGCATGGAATA  ...   0.000000   0.000000  0.015700   0.095114
# SMC01-N_AGAGCGAAGGGTTCCC  ...   0.000000   0.064210  0.015492   0.017224
# SMC01-N_ATGAGGGAGTTTGCGT  ...   0.000000   0.000000  0.062451   0.106239
# ...                       ...        ...        ...       ...        ...
# SMC10-N_TTATGCTTCCACGTGG  ...   0.000000   0.000000  0.008940   0.000000
# SMC10-N_TTCGGTCTCTATCGCC  ...   0.268994   0.000000  0.023188   0.000000
# SMC10-N_TTCTACAAGTCCTCCT  ...   0.136158   0.042049  0.056191   0.000000
# SMC10-N_TTCTCCTTCGACGGAA  ...   0.217796   0.044729  0.008370   0.000000
# SMC10-N_TTGAACGGTCTCCATC  ...   0.090265   0.045563  0.139411   0.000000
#
#                           ZNF770(+)  ZNF84(+)  ZNF91(+)  ZNF92(+)  ZSCAN29(+)  \
# Cell
# SMC01-N_AACTCCCGTCCCTACT   0.410970  0.062789  0.086668  0.000000    0.055181
# SMC01-N_AACTCTTGTGGCAAAC   0.018552  0.079800  0.098339  0.503427    0.026651
# SMC01-N_ACATACGCATGGAATA   0.003867  0.029951  0.092647  0.059542    0.082450
# SMC01-N_AGAGCGAAGGGTTCCC   0.000000  0.055296  0.026975  0.044766    0.067079
# SMC01-N_ATGAGGGAGTTTGCGT   0.055549  0.041532  0.072616  0.014230    0.061644
# ...                             ...       ...       ...       ...         ...
# SMC10-N_TTATGCTTCCACGTGG   0.012811  0.022958  0.044474  0.082644    0.053338
# SMC10-N_TTCGGTCTCTATCGCC   0.000434  0.036346  0.091634  0.000000    0.024020
# SMC10-N_TTCTACAAGTCCTCCT   0.037774  0.055295  0.068338  0.000152    0.028413
# SMC10-N_TTCTCCTTCGACGGAA   0.060160  0.098506  0.088338  0.000000    0.085532
# SMC10-N_TTGAACGGTCTCCATC   0.075603  0.058570  0.048045  0.010786    0.037602
#
#                            ZXDC(+)
# Cell
# SMC01-N_AACTCCCGTCCCTACT  0.000000
# SMC01-N_AACTCTTGTGGCAAAC  0.000000
# SMC01-N_ACATACGCATGGAATA  0.160538
# SMC01-N_AGAGCGAAGGGTTCCC  0.000000
# SMC01-N_ATGAGGGAGTTTGCGT  0.000000
# ...                            ...
# SMC10-N_TTATGCTTCCACGTGG  0.375971
# SMC10-N_TTCGGTCTCTATCGCC  0.000000
# SMC10-N_TTCTACAAGTCCTCCT  0.000000
# SMC10-N_TTCTCCTTCGACGGAA  0.000000
# SMC10-N_TTGAACGGTCTCCATC  0.000000
#
# [226 rows x 293 columns]

# %% [markdown]
# Downstream Analysis
#
#
# Needs Testing still

# %%
sc.pp.highly_variable_genes(adata)
adata = adata[:, adata.var['highly_variable']]

# %% [markdown]
# PCA run

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %% [markdown]
# Run TSNE and UMAP

# %%
sc.tl.tsne(adata)

# %%
sc.set_figure_params(frameon=False, dpi=150, fontsize=8)
sc.pl.tsne(adata, color=['Phenograph'], 
           title=['MigrDCverse'], ncols=3, color_map="Set1",
          save=' - MigrDCverse_Phenograph.svg')

# %%
embedding_pca_tsne = pd.DataFrame(adata.obsm['X_tsne'], columns=[['_X', '_Y']], index=adata.obs_names)

# %% [markdown]
# RUN TNSE UMAP on AUCell

# %%
add_scenic_metadata(adata, auc_mtx, regulons)
adata.write_h5ad(ANNDATA_FNAME)

# %%
print(len(auc_mtx))

# %%
auc_mtx

# %%
print (adata.n_obs)

# %% [markdown]
# We change the tSNE projection so that it relies on AUCell instead of PCA.

# %%
sc.tl.tsne(adata, use_rep='X_aucell')

# %%
auc_mtx_reindex = auc_mtx.reindex(adata.obs_names)
auc_mtx_reindex.head()

# %%
import umap
from MulticoreTSNE import MulticoreTSNE as TSNE

# UMAP
runUmap = umap.UMAP(n_neighbors=15, min_dist=0.1, metric='correlation').fit_transform
dr_umap = runUmap(auc_mtx_reindex)
pd.DataFrame(dr_umap, columns=['X', 'Y'], index=auc_mtx.index).to_csv( "Output/scenic_umap_IDO_Macs.txt", sep='\t')

# tSNE
tsne = TSNE( n_jobs=20 )
dr_tsne = tsne.fit_transform(auc_mtx_reindex)
pd.DataFrame(dr_tsne, columns=['X', 'Y'], index=auc_mtx.index).to_csv( "Output/scenic_tsne_IDO_macs.txt", sep='\t')

# %%
adata.obsm

# %%
adata.obsm['X_tsne'] = dr_tsne

# %%
adata.obsm['X_umap'] = dr_umap

# %%
adata.obs['Phenograph'] = adata.obs['Phenograph'].astype(str)
sc.pl.tsne(adata, color=['Phenograph'], palette="Paired", save='pdf');

# %%
sc.pl.umap(adata, color=['Tissue'], palette="Paired",save='UMAP_AUCELL_pdf_IDO_Macs_');

# %%
# adata.obsm['X_umap_offline']

# %%
df_dr_umap = pd.DataFrame(dr_umap, columns=['umap1', 'umap2'])
df_dr_umap.head()

# %%
# adata.obs['Phenograph'].values

# %%
df_dr_umap['celltype'] = adata.obs['Phenograph'].values
df_dr_umap['cellid'] = adata.obs_names.values
df_dr_umap.set_index('cellid', drop=True, inplace=True)
df_dr_umap.head()

# %%
# combine auc with the metadata
df_dr_umap_auc = pd.merge(auc_mtx_reindex, df_dr_umap, how='inner',  left_index=True, right_index=True)
df_dr_umap_auc.head()

# %%
df_dr_umap_auc.to_csv('Output/dr_umap_auc_IDO_Macs_transformed.csv', sep=',')

# %%
pd.read_csv('output/dr_umap_auc_Maier.csv', sep=',', index_col=0)

# %% [markdown]
# ### plotting

# %%
df_dr_umap['celltype'] = df_dr_umap['celltype'].astype(str)

# %%
df_dr_umap.dtypes

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

ax = sns.scatterplot(x="umap1", y="umap2", hue="celltype", s=5,
                     data=df_dr_umap)
ax

# %%
sc.set_figure_params(frameon=False, dpi=600, fontsize=10, dpi_save=600)

sc.pl.scatter( dr_umap, 
    color=['Phenograph'],
    title=['HVG - UMAP (UMAP AUcell)'],
    alpha=0.8,
    save='_MigrDC_AUcell_UMAP.pdf'
    )

# %%
sc.pl.scatter(adata, 
    x = adata.obsm['X_umap_offline'][:, 0],
    y = adata.obsm['X_umap_offline'][:, 1],
    color=['Phenograph'],
    title=['HVG - UMAP (UMAP AUcell)'],
    alpha=0.8,
    save='_MigrDC_AUcell_UMAP_test.pdf'
    )

# %%
# adata.obs.Phenograph
adata.obs['Phenograph']

# %%
sns.set()
sns.set(style='whitegrid', font_scale=0.8)
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8)) = plt.subplots(2, 4, figsize=(8, 6), dpi=100)
plot_rss(rss, '1', ax=ax1)
ax1.set_xlabel('')
plot_rss(rss, '2', ax=ax2)
ax2.set_xlabel('')
ax2.set_ylabel('')
plot_rss(rss, '3', ax=ax3)
ax3.set_xlabel('')
ax3.set_ylabel('')
plot_rss(rss, '4', ax=ax4)
ax4.set_xlabel('')
ax4.set_ylabel('')
plot_rss(rss, '5', ax=ax5)
plot_rss(rss, '6', ax=ax6)
ax6.set_ylabel('')
plot_rss(rss, '7', ax=ax7)
ax7.set_ylabel('')
plot_rss(rss, '8', ax=ax8)
ax8.set_ylabel('')
plt.tight_layout()
savesvg('plots - GSE103322 - rss.svg', fig)

# %% [markdown]
# Regulon analysis

# %%
df_obs = adata.obs
signature_column_names = list(df_obs.select_dtypes('number').columns)
signature_column_names = list(filter(lambda s: s.startswith('Regulon('), signature_column_names))
df_scores = df_obs[signature_column_names + ['Phenograph']]
df_results = ((df_scores.groupby(by='Phenograph').mean() - df_obs[signature_column_names].mean())/ df_obs[signature_column_names].std()).stack().reset_index().rename(columns={'level_1': 'regulon', 0:'Z'})
df_results['regulon'] = list(map(lambda s: s[8:-1], df_results.regulon))
df_results[(df_results.Z >= 3.0)].sort_values('Z', ascending=False).head()

# %%
df_heatmap = pd.pivot_table(data=df_results[df_results.Z >= 2.0].sort_values('Z', ascending=False),
                           index='Phenograph', columns='regulon', values='Z')
#df_heatmap.drop(index='Myocyte', inplace=True) # We leave out Myocyte because many TFs are highly enriched (becuase of small number of cells).
fig, ax1 = plt.subplots(1, 1, figsize=(10, 8))
sns.heatmap(df_heatmap, ax=ax1, annot=True, fmt=".1f", linewidths=.7, cbar=False, square=True, linecolor='gray', 
            cmap="YlGnBu", annot_kws={"size": 6})
ax1.set_ylabel('')
savesvg('heatmap - MigrDCall - regulons.svg', fig)

# %% [markdown]
# Caluclation of specific regulons on the Scenic
# Change per data analysis

# %%
data=df_results[df_results.Z >= 1.0].sort_values('Z', ascending=False)
df_results.to_csv('Maier_Regulon_Z_Score_Pheno_1_5_7OUT.csv',sep=',')

# %%
sc.pl.umap(adata, color=['Phenograph', 'Regulon(STAT2(+))', 'Regulon(BATF(+))'],
           title=['MigrDCMaier - HNSC - Phenograph', 'STAT2', 'BATF'], ncols=3, use_raw=False,
          save=' - Maier_MigrDC - regulons_STAT2_BATF.svg')
